# %%
# !pip install pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_parquet('.\data\Label\LABEL_BTCUSDT\SYMBOL=BTCUSDT.parquet')

# %%
print(df)
# Out:
#                SYMBOL     LABEL
# OPEN_TIME
# 1.505556e+12  BTCUSDT  0.393885
# 1.505560e+12  BTCUSDT  0.390215
# 1.505563e+12  BTCUSDT  0.360434
# 1.505567e+12  BTCUSDT  0.398650
# 1.505570e+12  BTCUSDT  0.451718
# ...               ...       ...
# 1.677611e+12  BTCUSDT  0.448246
# 1.677614e+12  BTCUSDT  0.470401
# 1.677618e+12  BTCUSDT  0.468764
# 1.677622e+12  BTCUSDT  0.474988
# 1.677625e+12  BTCUSDT  0.484824
#
# [47677 rows x 2 columns]

# %%
keys = list(df)
print(keys)
# Out:
# ['OPEN', 'HIGH', 'LOW', 'CLOSE', 'VOLUME', 'QUOTE_ASSET_VOLUME', 'NUMBER_OF_TRADES', 'TAKER_BUY_BASE_ASSET_VOLUME', 'TAKER_BUY_QUOTE_ASSET_VOLUME', 'YEAR_AND_MONTH']

# %%
import matplotlib.pyplot as plt

# Vẽ biểu đồ đường
plt.plot(df.index, df['VOLUME'])
plt.xlabel('OPEN_TIME')
plt.ylabel('CLOSE')
plt.title('Price Trend')
plt.xticks(rotation=45)
plt.show()

# %%
plt.plot(df.index, df['TAKER_BUY_BASE_ASSET_VOLUME'])
plt.plot(df.index, df['TAKER_BUY_QUOTE_ASSET_VOLUME'])
plt.xlabel('OPEN_TIME')
plt.ylabel('CLOSE')
plt.title('Price Trend')
plt.xticks(rotation=45)
plt.show()

# %%
plt.plot(df.index, df['NUMBER_OF_TRADES'])
plt.xlabel('OPEN_TIME')
plt.ylabel('CLOSE')
plt.title('Price Trend')
plt.xticks(rotation=45)
plt.show()
